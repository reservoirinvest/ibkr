# %%
from ib_insync import *
util.startLoop()
ib = IB().connect('127.0.0.1', 1300, clientId=15)

# %%
import pandas as pd
pd.read_pickle('./zdata/_TXN.pkl')
# Out:
# {'symbol': 'TXN',
#  'bars': [BarData(date=datetime.date(2018, 1, 24), open=111.14, high=114.0, low=108.68, close=109.7, volume=162424, barCount=86744, average=111.276),
#   BarData(date=datetime.date(2018, 1, 25), open=110.84, high=111.71, low=109.08, close=110.15, volume=63061, barCount=40559, average=110.474),
#   BarData(date=datetime.date(2018, 1, 26), open=111.14, high=114.0, low=109.54, close=113.69, volume=53710, barCount=34213, average=112.0235),
#   BarData(date=datetime.date(2018, 1, 29), open=112.47, high=113.4, low=111.25, close=112.65, volume=41213, barCount=27643, average=112.4585),
#   BarData(date=datetime.date(2018, 1, 30), open=111.2, high=111.47, low=109.3, close=109.89, volume=46330, barCount=29846, average=110.303),
#   BarData(date=datetime.date(2018, 1, 31), open=110.93, high=110.99, low=108.3, close=109.67, volume=54347, barCount=35633, average=109.1765),
# ...
