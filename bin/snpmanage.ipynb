# %%
# Order preparation for SnP

# STATUS: Incomplete
# Run-time: 10 seconds

# Dependencies:
# /zdata/pkls/*.pkl - for pickles generated by 01_snp_scan program

#***          Start ib_insync (run once)       *****
#_______________________________________________

from ib_insync import *
util.startLoop()
ib = IB().connect('127.0.0.1', 1300, clientId=0)

# %%
# %%time
import datetime
import pandas as pd
import numpy as np
from os import listdir
import math
import datetime
import itertools

from helper import get_dte, get_prec, grp_opts, filter_kxdte, get_onlyputs, get_hvstpricepct, get_opt_margin

#...assignments
#______________

fspath = '../data/snp/'

m_maxp = 0.015    # % of max margin allowed on net liquidity per scrip to limit positon risk
base = 0.01       # Upper or Lower base multiple for prices
expmult = 1.1    # expected multiple of price (1.05 means 5% higher)
desired_rom = 0.8 # desired rom to give the target price.

ass_limit = 40000.0   # max allowable assignment limit

min_rom = 0.80
min_pop = 0.85
min_dte = 45    # no of minimum dte days to determine ohlc filter for strikes

max_nlvp = 0.8    # max allowable nlv to prevent overall portfolio risk. 0.8 means 80% of NLV.
                  # max available funds for option trades = max_nlvp * NLV - initMargin

dow30 = list(pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average', header=0)[1].Symbol)

# from https://www.fool.com/slideshow/25-top-performing-sp-500-stocks-2018
dowtop2018 = ['AMD', 'ABMD', 'FTNT', 'TRIP', 'AAP', 'RHT', 'CMG', 'KEYS', 'ORLY', 'FOX', 'HCA', 
             'BSX', 'MCK', 'ILMN', 'NRG', 'MRK', 'LLY', 'NFLX', 'EW', 'CRM', 'AES', 'RMD', 'CHD', 'LW', 'VRSN']

topstocks = set(dow30 + dowtop2018)

#...get current positions
#________________________

#... read the account info
ac = ib.accountValues()
df_a = util.df(ac)

#... set max margin per position
net_liq = float(df_a[df_a.tag == 'NetLiquidation'].iloc[0].value) 
av_funds = float(df_a[df_a.tag == 'FullAvailableFunds'].iloc[0].value)
max_p = net_liq*m_maxp

#...Harvest preparation
#______________________

#... read the positions
ps = ib.portfolio()

# Do harvesting only if there is something in the portfolio
if ps:
    df_p = util.df(ps)

    #...identify Stock and Option
    rights = [o.right for o in df_p.contract]
    df_p = df_p.assign(right=rights)

    df_p = df_p.assign(type=[type(x).__name__ for x in df_p.contract])

    df_p['symbol'] = [s.symbol for s in df_p.contract.values]

    # harvest option Dataframe
    df_hop = df_p[df_p.type == 'Option'].reset_index(drop=True)

    #... get the harvest as lower of discount from curve * averageCost and discount * marketPrice
    
    df_hop = df_hop.assign(averageCost=df_hop.averageCost/100) # Correct the average cost for options
    
    expiry = [d.lastTradeDateOrContractMonth for d in df_hop.contract]

    df_hop['dte'] = [get_dte(d.lastTradeDateOrContractMonth) for d in df_hop.contract]

    discount = [m for m in map(get_hvstpricepct, expiry)]
    df_hop['hvstPrice'] = pd.concat([df_hop.averageCost*discount, 
                                   df_hop.marketPrice*(1-np.array(discount))], axis=1).min(axis=1)

    df_hop.hvstPrice = np.floor(df_hop.hvstPrice/base)*base # round down to the nearest 0.05

    df_hop.loc[df_hop.hvstPrice == 0, 'hvstPrice'] = base  # make the 0s to 5 paise

    # harvest open positions with hvstPrice
    df_hop['harvestOrder'] = [LimitOrder(action='BUY', totalQuantity=-position, lmtPrice=hvstPrice) for position, hvstPrice in zip(df_hop.position, df_hop.hvstPrice)]

    # ignore data for dte < 3 days. These are as good as gone.
    df_h = df_hop[df_hop.dte > 3].reset_index(drop=True)

    hqc = ib.qualifyContracts(*df_h.contract)
    df_h = df_h.assign(qual_contract=hqc)

    # ...sowing prepration
    #_____________________

    #... find margins
    orders = [Order(action=np.where(q>0, 'SELL', 'BUY'), totalQuantity=abs(q), orderType='MKT') for q in df_p.position]

    cs = list(df_p.contract)
    qc = ib.qualifyContracts(*cs)
    df_p = df_p.assign(margin=[float(ib.whatIfOrder(c, o).initMarginChange) for c, o in zip(qc, orders)])
    df_p['lot'] = np.where(df_p.type == 'Option', df_p.position*100, df_p.position)

    #... make the blacklist
    df2 = df_p.groupby(['symbol']).sum()
    df2['max_margin'] = -max_p

    df2['avail_margin'] = df2.max_margin - df2.margin

    # determine no of units free
    df2['remqty'] = -(df2.avail_margin/df2.margin/df2.lot/100).apply(np.floor)
    df2.loc[df2.remqty <= 0, 'remqty'] = 0

    blacklist = list(df2[df2.remqty <= 0].index)

    # get remaining lots of partially filled symbols
    not_black = df2[df2.remqty > 0][['remqty']].to_dict('dict')
    remqtydict = [v for k, v in not_black.items()][0]
else:
    blacklist = []
    remqtydict = []

#...build the high-pop-roc dataframe
fs = listdir(fspath)

opts = ([f[:-8]+'_opt.pkl' for f in fs if f[-8:] == '_opt.pkl'])
ohlcs = ([f[:-8]+'_ohlc.pkl' for f in fs if f[-8:] == '_opt.pkl'])
unds = ([f[:-8]+'_und.pkl' for f in fs if f[-8:] == '_opt.pkl'])

df_opt = pd.concat([pd.read_pickle(fspath+f) for f in opts], axis=0, sort=True).reset_index(drop=True).sort_values('rom', ascending=False)
df_ohlc = pd.concat([pd.read_pickle(fspath+f).reset_index() for f in ohlcs], axis=0, sort=True)
df_und = pd.concat([pd.read_pickle(fspath+f) for f in unds])

# remove options in black list
df_opt = df_opt[~df_opt.symbol.isin(blacklist)]

# arrange the columns
cols = ['symbol', 'right', 'expiry', 'dte', 'strike', 'undPrice', 'lo52',  'hi52', 
'stdev', 'volatility', 'margin', 'lot', 'bsmPrice', 'pop', 'rom', 'price', 'option']

df_opt1 = df_opt[cols]

# take only high pops
df_opt2 = df_opt1[df_opt1['pop'] >= min_pop].reset_index(drop=True)

# take only top stocks
# df_opt2 = df_opt2[df_opt2.symbol.isin(topstocks)]

# take only puts
df_opt3 = get_onlyputs(df_opt2)

# keep only options with prices
df_opt3 = df_opt3[df_opt3.price > 0]

df_opt3 = df_opt3.sort_values('rom', ascending = False)  

df_opt3 = df_opt3[df_opt3.rom > min_rom] # Limit above minimum rom
# Out:
# Wall time: 11.5 s

# %%
df_opt3
# Out:
#     symbol right    expiry  dte  strike  undPrice    lo52  hi52      stdev  \
# 0     QCOM     P  20190412   21    49.0     58.09   48.56   NaN   1.629540
# 1     DUST     P  20190503   42    14.5     18.23   15.75   NaN   2.142688
# 2     QCOM     P  20190412   21    46.0     58.09   48.56   NaN   1.629540
# 3     DUST     P  20190503   42    13.5     18.23   15.75   NaN   2.142688
# 4     QCOM     P  20190412   21    45.0     58.09   48.56   NaN   1.629540
# 5     QCOM     P  20190426   35    45.0     58.09   48.56   NaN   2.289897
# 6     QCOM     P  20190426   35    49.0     58.09   48.56   NaN   2.289897
# 7     AMGN     P  20190426   35   177.5    191.81  163.31   NaN   2.868591
# 8     QCOM     P  20190418   27    44.0     58.09   48.56   NaN   1.893806
# 9     AMGN     P  20190418   27   177.5    191.81  163.31   NaN   3.040972
# 10    AMGN     P  20190412   21   177.5    191.81  163.31   NaN   3.371434
# 11    DUST     P  20190503   42    14.0     18.23   15.75   NaN   2.142688
# 12    QCOM     P  20190418   27    43.0     58.09   48.56   NaN   1.893806
# 13    QCOM     P  20190418   27    49.0     58.09   48.56   NaN   1.893806
# 14    VIXY     P  20190503   42    20.0     23.56   21.27   NaN   2.641595
# 15    ABBV     P  20190426   35    73.5     80.38   75.77   NaN   0.910044
# 16    AMGN     P  20190503   42   177.5    191.81  163.31   NaN   5.178460
# 17     UNH     P  20190418   27   230.0    252.15  212.49   NaN  10.963207
# 18    GILD     P  20190503   42    58.5     64.28   60.32   NaN   1.990375
# 19    AMGN     P  20190426   35   172.5    191.81  163.31   NaN   2.868591
# 20    GILD     P  20190503   42    59.0     64.28   60.32   NaN   1.990375
# 21     UNH     P  20190426   35   230.0    252.15  212.49   NaN  11.360668
# 22    AMGN     P  20190412   21   165.0    191.81  163.31   NaN   3.371434
# 23     UNH     P  20190503   42   230.0    252.15  212.49   NaN  10.980396
# 24    AMGN     P  20190412   21   162.5    191.81  163.31   NaN   3.371434
# 25    QCOM     P  20190412   21    47.0     58.09   48.56   NaN   1.629540
# 26    QCOM     P  20190412   21    48.0     58.09   48.56   NaN   1.629540
# 27    AMGN     P  20190426   35   170.0    191.81  163.31   NaN   2.868591
# 28    AMGN     P  20190412   21   160.0    191.81  163.31   NaN   3.371434
# 29    GILD     P  20190503   42    59.5     64.28   60.32   NaN   1.990375
# ..     ...   ...       ...  ...     ...       ...     ...   ...        ...
# 93     UNH     P  20190426   35   220.0    252.15  212.49   NaN  11.360668
# 94    ABBV     P  20190426   35    73.0     80.38   75.77   NaN   0.910044
# 95     UNH     P  20190503   42   215.0    252.15  212.49   NaN  10.980396
# 96     BMY     P  20190503   42    44.0     48.92   44.30   NaN   1.231192
# 97     BMY     P  20190426   35    44.0     48.92   44.30   NaN   1.154075
# 98     WBA     P  20190412   21    58.0     63.72   59.07   NaN   4.319592
# 99    ABBV     P  20190418   27    74.5     80.38   75.77   NaN   0.970789
# 100   AMGN     P  20190418   27   167.5    191.81  163.31   NaN   3.040972
# 101    UNH     P  20190412   21   220.0    252.15  212.49   NaN  10.157270
# 102    WBA     P  20190418   27    58.0     63.72   59.07   NaN   4.866438
# 103    WBA     P  20190503   42    58.0     63.72   59.07   NaN   4.552198
# 104   AMGN     P  20190517   56   165.0    191.81  163.31   NaN   5.959762
# 105    UNH     P  20190412   21   225.0    252.15  212.49   NaN  10.157270
# 106    UNH     P  20190426   35   212.5    252.15  212.49   NaN  11.360668
# 107    WBA     P  20190426   35    58.0     63.72   59.07   NaN   4.714862
# 108   DUST     P  20190412   21    15.0     18.23   15.75   NaN   1.120410
# 109    UNH     P  20190412   21   222.5    252.15  212.49   NaN  10.157270
# 110    UNH     P  20190426   35   217.5    252.15  212.49   NaN  11.360668
# 111   ABBV     P  20190418   27    74.0     80.38   75.77   NaN   0.970789
# 112    UNH     P  20190412   21   212.5    252.15  212.49   NaN  10.157270
# 113    SCO     P  20190418   27    15.0     16.97   12.29   NaN   1.143430
# 114   UVXY     P  20190418   27    32.5     38.04    7.59   NaN   3.482079
# 115   ABBV     P  20190412   21    74.0     80.38   75.77   NaN   0.998596
# 116   JDST     P  20190412   21    29.0     35.88   30.60   NaN   3.209378
# 117    WBA     P  20190412   21    57.5     63.72   59.07   NaN   4.319592
# 118    SCO     P  20190412   21    15.0     16.97   12.29   NaN   0.802395
# 119    WBA     P  20190503   42    57.5     63.72   59.07   NaN   4.552198
# 120   AMGN     P  20190418   27   165.0    191.81  163.31   NaN   3.040972
# 121   DUST     P  20190418   27    15.0     18.23   15.75   NaN   1.116377
# 122    UNH     P  20190426   35   210.0    252.15  212.49   NaN  11.360668
#
#      volatility   margin  lot  bsmPrice       pop       rom  price  \
# 0      0.145343    62.21  100      0.00  1.000000  4.629481  0.240
# 1      0.698430   344.96  100      0.35  0.857701  4.087430  2.350
# 2      0.145343    62.21  100      0.00  1.000000  3.857901  0.200
# 3      0.698430   344.96  100      0.19  0.914916  3.739564  2.150
# 4      0.145343    62.21  100      0.00  1.000000  3.568558  0.185
# 5      0.145728    62.21  100      0.00  1.000000  2.661951  0.230
# 6      0.145728    62.21  100      0.00  0.999930  2.604083  0.225
# 7      0.186010   597.58  100      0.41  0.920335  2.433816  2.020
# 8      0.136355    62.21  100      0.00  1.000000  2.400472  0.160
# 9      0.167242   597.58  100      0.14  0.960712  2.397447  1.535
# 10     0.173697   597.58  100      0.09  0.971850  2.279193  1.135
# 11     0.698430   344.96  100      0.26  0.888419  2.261132  1.300
# 12     0.136355    62.21  100      0.00  1.000000  2.250442  0.150
# 13     0.136355    62.21  100      0.00  0.999998  2.250442  0.150
# 14     0.459634   415.64  100      0.25  0.874282  2.201424  1.525
# 15     0.151492   522.80  100      0.04  0.974764  2.155318  1.565
# 16     0.215838   597.58  100      0.94  0.869963  2.133606  2.125
# 17     0.309801   511.80  100      1.36  0.875246  2.097173  1.150
# 18     0.218040   419.90  100      0.21  0.907432  2.093356  1.465
# 19     0.186010   597.58  100      0.12  0.971505  2.036213  1.690
# 20     0.218040   419.90  100      0.27  0.886869  2.036199  1.425
# 21     0.287115   511.80  100      1.60  0.864545  2.025791  1.440
# 22     0.173697   597.58  100      0.00  0.999875  2.008099  1.000
# 23     0.265796   511.80  100      1.65  0.862432  1.951934  1.665
# 24     0.173697   597.58  100      0.00  0.999972  1.947856  0.970
# 25     0.145343    62.21  100      0.00  1.000000  1.928950  0.100
# 26     0.145343    62.21  100      0.00  1.000000  1.928950  0.100
# 27     0.186010   597.58  100      0.06  0.984491  1.927775  1.600
# 28     0.173697   597.58  100      0.00  0.999995  1.907694  0.950
# 29     0.218040   419.90  100      0.34  0.863449  1.893308  1.325
# ..          ...      ...  ...       ...       ...       ...    ...
# 93     0.287115   511.80  100      0.54  0.945305  1.019930  0.725
# 94     0.151492   522.80  100      0.02  0.982200  1.019128  0.740
# 95     0.265796   511.80  100      0.30  0.967065  1.008206  0.860
# 96     0.215699   319.74  100      0.11  0.932143  1.003941  0.535
# 97     0.225018   319.74  100      0.09  0.940845  0.990805  0.440
# 98     0.326867   408.14  100      0.26  0.893517  0.984956  0.335
# 99     0.136892   522.80  100      0.02  0.981389  0.972966  0.545
# 100    0.167242   597.58  100      0.00  0.998793  0.968350  0.620
# 101    0.328121   511.80  100      0.30  0.963075  0.949590  0.405
# 102    0.327009   408.14  100      0.40  0.866389  0.937587  0.410
# 103    0.269806   408.14  100      0.43  0.860985  0.918802  0.625
# 104    0.225063   597.58  100      0.26  0.962940  0.896114  1.190
# 105    0.328121   511.80  100      0.60  0.933452  0.890973  0.380
# 106    0.287115   511.80  100      0.20  0.976763  0.886284  0.630
# 107    0.292413   408.14  100      0.42  0.862920  0.873230  0.495
# 108    0.665736   344.96  100      0.14  0.901517  0.869666  0.250
# 109    0.328121   511.80  100      0.43  0.949909  0.867526  0.370
# 110    0.287115   511.80  100      0.39  0.958139  0.865182  0.615
# 111    0.136892   522.80  100      0.01  0.988219  0.856924  0.480
# 112    0.328121   511.80  100      0.09  0.987068  0.855803  0.365
# 113    0.402179   220.35  100      0.11  0.884833  0.847137  0.200
# 114    0.608921  1013.35  100      0.52  0.851811  0.838144  0.910
# 115    0.147082   522.80  100      0.01  0.991385  0.837796  0.365
# 116    0.867158   682.11  100      0.53  0.870046  0.835642  0.475
# 117    0.326867   408.14  100      0.21  0.912431  0.823247  0.280
# 118    0.411323   220.35  100      0.08  0.905652  0.816882  0.150
# 119    0.269806   408.14  100      0.35  0.880871  0.815897  0.555
# 120    0.167242   597.58  100      0.00  0.999616  0.812165  0.520
# 121    0.696427   344.96  100      0.25  0.867043  0.811688  0.300
# 122    0.287115   511.80  100      0.14  0.983172  0.801876  0.570
#
#                                                 option
# 0    Option(conId=355483855, symbol='QCOM', lastTra...
# 1    Option(conId=358238774, symbol='DUST', lastTra...
# 2    Option(conId=355483817, symbol='QCOM', lastTra...
# 3    Option(conId=358238759, symbol='DUST', lastTra...
# 4    Option(conId=355686708, symbol='QCOM', lastTra...
# 5    Option(conId=356492757, symbol='QCOM', lastTra...
# 6    Option(conId=356241251, symbol='QCOM', lastTra...
# 7    Option(conId=356149402, symbol='AMGN', lastTra...
# 8    Option(conId=352536657, symbol='QCOM', lastTra...
# 9    Option(conId=357382393, symbol='AMGN', lastTra...
# 10   Option(conId=355394194, symbol='AMGN', lastTra...
# 11   Option(conId=358238780, symbol='DUST', lastTra...
# 12   Option(conId=352536640, symbol='QCOM', lastTra...
# 13   Option(conId=352536700, symbol='QCOM', lastTra...
# 14   Option(conId=358330963, symbol='VIXY', lastTra...
# 15   Option(conId=356144854, symbol='ABBV', lastTra...
# 16   Option(conId=358205703, symbol='AMGN', lastTra...
# 17   Option(conId=350805999, symbol='UNH', lastTrad...
# 18   Option(conId=358254833, symbol='GILD', lastTra...
# 19   Option(conId=356149377, symbol='AMGN', lastTra...
# 20   Option(conId=358254875, symbol='GILD', lastTra...
# 21   Option(conId=356276408, symbol='UNH', lastTrad...
# 22   Option(conId=355394163, symbol='AMGN', lastTra...
# 23   Option(conId=358323154, symbol='UNH', lastTrad...
# 24   Option(conId=355394152, symbol='AMGN', lastTra...
# 25   Option(conId=355483826, symbol='QCOM', lastTra...
# 26   Option(conId=355483837, symbol='QCOM', lastTra...
# 27   Option(conId=356149361, symbol='AMGN', lastTra...
# 28   Option(conId=355394146, symbol='AMGN', lastTra...
# 29   Option(conId=358254858, symbol='GILD', lastTra...
# ..                                                 ...
# 93   Option(conId=356276390, symbol='UNH', lastTrad...
# 94   Option(conId=356144864, symbol='ABBV', lastTra...
# 95   Option(conId=358323080, symbol='UNH', lastTrad...
# 96   Option(conId=358219377, symbol='BMY', lastTrad...
# 97   Option(conId=356989072, symbol='BMY', lastTrad...
# 98   Option(conId=356269227, symbol='WBA', lastTrad...
# 99   Option(conId=357363623, symbol='ABBV', lastTra...
# 100  Option(conId=357382356, symbol='AMGN', lastTra...
# 101  Option(conId=355510957, symbol='UNH', lastTrad...
# 102  Option(conId=357807646, symbol='WBA', lastTrad...
# 103  Option(conId=358329900, symbol='WBA', lastTrad...
# 104  Option(conId=353820974, symbol='AMGN', lastTra...
# 105  Option(conId=355510987, symbol='UNH', lastTrad...
# 106  Option(conId=356276373, symbol='UNH', lastTrad...
# 107  Option(conId=356269777, symbol='WBA', lastTrad...
# 108  Option(conId=355428791, symbol='DUST', lastTra...
# 109  Option(conId=355510972, symbol='UNH', lastTrad...
# 110  Option(conId=356276387, symbol='UNH', lastTrad...
# 111  Option(conId=357363641, symbol='ABBV', lastTra...
# 112  Option(conId=356276060, symbol='UNH', lastTrad...
# 113  Option(conId=330541588, symbol='SCO', lastTrad...
# 114  Option(conId=357765945, symbol='UVXY', lastTra...
# 115  Option(conId=355389872, symbol='ABBV', lastTra...
# 116  Option(conId=356997550, symbol='JDST', lastTra...
# 117  Option(conId=356269193, symbol='WBA', lastTrad...
# 118  Option(conId=355485531, symbol='SCO', lastTrad...
# 119  Option(conId=358329860, symbol='WBA', lastTrad...
# 120  Option(conId=330192444, symbol='AMGN', lastTra...
# 121  Option(conId=353919751, symbol='DUST', lastTra...
# 122  Option(conId=356276368, symbol='UNH', lastTrad...
#
# [123 rows x 17 columns]

# %%
df_opt4 = df_opt3.assign(margin=[get_opt_margin(ib, o, l) for o, l in zip(df_opt3.option, itertools.repeat(1))])

df_opt4 = df_opt4[df_opt4.margin < df_opt4.strike*df_opt4.lot] # remove 1.7976931348623157e+308 from margins!

# get the better of Price and bsmPrice for the option - with an expected multiple (expmult)
max_price_bsm = pd.concat([df_opt4.price, df_opt4.bsmPrice], axis=1).max(axis=1)
df_opt4['expPrice'] = get_prec(max_price_bsm*expmult, base)

df_opt4 = df_opt4.assign(rom=df_opt4.expPrice*df_opt4.lot/df_opt4.margin*365/df_opt4.dte).reset_index(drop=True).sort_values('rom', ascending=False)
# Out:
# Error 201, reqId 406: Order rejected - reason:Order Reject: This account cannot have open orders on both sides
# of the same US Option contract in any related accounts., contract: Option(conId=350805984, symbol='UNH', lastTradeDateOrContractMonth='20190418', strike=220.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='UNH   190418P00220000', tradingClass='UNH')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5d030db791fa> in <module>
# ----> 1 df_opt4 = df_opt3.assign(margin=[get_opt_margin(ib, o, l) for o, l in zip(df_opt3.option, itertools.repeat(1))])
#       2
#       3 df_opt4 = df_opt4[df_opt4.margin < df_opt4.strike*df_opt4.lot] # remove 1.7976931348623157e+308 from margins!
#       4
#       5 # get the better of Price and bsmPrice for the option - with an expected multiple (expmult)
#
# <ipython-input-11-5d030db791fa> in <listcomp>(.0)
# ----> 1 df_opt4 = df_opt3.assign(margin=[get_opt_margin(ib, o, l) for o, l in zip(df_opt3.option, itertools.repeat(1))])
#       2
#       3 df_opt4 = df_opt4[df_opt4.margin < df_opt4.strike*df_opt4.lot] # remove 1.7976931348623157e+308 from margins!
#       4
#       5 # get the better of Price and bsmPrice for the option - with an expected multiple (expmult)
#
# ~\Documents\ibkr\bin\helper.py in get_opt_margin(ib, contract, mult)
#     395     order = Order(action='SELL', totalQuantity=mult, orderType='MKT')
#     396
# --> 397     margin = float(ib.whatIfOrder(contract, order).initMarginChange)
#     398
#     399     return margin
#
# AttributeError: 'list' object has no attribute 'initMarginChange'

# %%
# Make df the dataframe that you want to execute on!
df = df_opt4.copy()   # make this the last dataframe to get the orders placed

df.loc[df.expPrice < 0.2, 'expPrice'] = 0.2  # Make the selling price a minimum of 0.2

contracts = [c for c in df.option]

df = df.assign(qty=pd.concat([round(ass_limit / (df.strike * df.lot)), 
                         round(max_p/df.margin)], axis=1).min(axis=1))

# df = df.assign(qty=1) # defaults to a quantity of 1
    
print('{:d} contracts from {:d} scrips, consuming {:,.0f} margin from full available funds of {:,.0f}, giving USD {:,.0f}'.format(len(contracts), \
      len(df.symbol.unique()), sum(df.margin*df.qty), av_funds*max_nlvp, sum(df.expPrice*df.lot*df.qty)))

# %%
# ...review calls and puts
# e.g. for puts from path: C:\Users\kashir\Documents\IBKR\snp\zdata\putswatch.csv
# .....,, or in this path: C:\Users\User\Documents\ibkr\snp\zdata\putswatch.csv (home laptop)

# add tgtPrice based on desired rom
df['tgtPrice'] = get_prec(pd.concat([df.rom, pd.Series(desired_rom, index=df.index)], axis=1).max(axis=1)*df.expPrice/df.rom, base)

df['remqty'] = round(max_p/df.margin)

# replace remqty with non-blacklist remaining quantities
if ps:
    df = df.set_index('symbol')
    df.remqty = np.where(df.index.isin(remqtydict.keys()), df.index.map(remqtydict), df.remqty) 
    df = df.reset_index()

# Sort the calls and puts by symbol and strikes - to quickly weed out risky options
df = grp_opts(df)

cols = ['right', 'symbol', 'strike', 'undPrice', 'dte', 'pop', 'rom', 'price', 'expPrice', 'margin', 'lot', 'qty', 'remqty', 'tgtPrice', 'option']
df = df[cols]

# make watchlists
df_puts = df[df.right == 'P'].reset_index(drop=True)
df_calls = df[df.right == 'C'].reset_index(drop=True)

if not df_puts.empty:
    watchputs = [('DES', s, 'STK', 'SMART/ARCA') for s in df_puts.symbol.unique()]
    df_wp = util.df(watchputs)
    df_wp.to_csv(fspath+'putswatch.csv', index=None, header=False)

if not df_calls.empty:
    watchcalls = [('DES', s, 'STK', 'SMART/ARCA') for s in df_calls.symbol.unique()]
    df_wc = util.df(watchcalls)
    df_wc.to_csv(fspath+'.callswatch.csv', index=None, header=False)

df.to_csv(fspath+'check.csv', index=None, header=True)

# %%
# .......for puts from path: C:\Users\kashir\Documents\IBKR\snp\zdata\putswatch.csv
# ....... or in this path: C:\Users\User\Documents\ibkr\snp\zdata\putswatch.csv (home laptop)
# After going through checked.csv, with puts and calls, eliminate risky options
# Save the file as checked.csv

df_final = pd.read_csv(fspath+'checked.csv') # picks up the checked and ready-to-go contracts
cs = [eval(c) for c in df_final.option]  # convert the "quoted strings" from csv back to object
orders = [LimitOrder(action='SELL', totalQuantity=qty, lmtPrice=tgtPrice) for qty, tgtPrice in zip(df_final.qty, df_final.tgtPrice)]
print('{:d} contracts from {:d} scrips, consuming {:,.0f} margin from full available funds of {:,.0f}, giving USD {:,.0f} in premiums.'.format(len(df_final), \
      len(df_final.symbol.unique()), sum(df_final.margin*df_final.qty), av_funds*max_nlvp, sum(df_final.tgtPrice*df_final.qty*100)))

# %%
# look at the amount of margin consumed
df_final.assign(totmargin = df_final.margin * df_final.qty).groupby('symbol', as_index=False).agg({'totmargin' : 'sum'}).sort_values('totmargin', ascending=False).reset_index(drop=True)

# %% [raw]
# #----------------------------------------------------
# # WARNING: THIS SECTION PLACES CLOSING HARVEST TRADES
# #____________________________________________________
# # ... code to delete BUY (harvest) orders first
# openords = ib.openOrders()
# buyords = [ords for ords in openords if ords.action == 'BUY'] # Buy orders
# cancelbuys = [ib.cancelOrder(s) for s in buyords]
# ib.sleep(3)
# closingTrades = [ib.placeOrder(contract, order) for contract, order in zip(df_h.qual_contract, df_h.harvestOrder)]

# %% [raw]
# #-------------------------------------------------------------------
# # WARNING: THIS SECTION PLACES OPENING (SOW) TRADES FROM checked.csv
# #___________________________________________________________________
# # ... code to delete SELL (sow) orders first
# # openords = ib.openOrders()
# # sellords = [ords for ords in openords if ords.action == 'SELL'] # SELL orders
# # cancelsells = [ib.cancelOrder(s) for s in sellords]
# # ib.sleep(3)
# openingTrades = [ib.placeOrder(contract, order) for contract, order in zip(cs, orders)]

# %% [raw]
# #----------------------------------------------------
# # WARNING: THIS SECTION CANCELS ALL OPEN ORDERS
# #____________________________________________________
# cancels = ib.reqGlobalCancel()
