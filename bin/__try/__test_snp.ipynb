# %%
# snp scratchpad initiation
from helper import *
from snp_func import *

# Do assignments
a = assign_var('snp')
for v in a:
    exec(v)

from ib_insync import *
util.startLoop()

ib =  get_connected('snp', 'paper')

# %%
# %%time
with open(logpath+'build.log', 'w'):
    pass # clear the run log

util.logToFile(logpath+'build.log')
opts(ib)

# %%
dft = pd.read_pickle(fspath+'opts.pickle').dropna()
dft[dft.rom>0.25].symbol.unique()
# Out:
# array(['KHC', 'COST', 'PM', 'MDT', 'LOW', 'MO', 'ADBE', 'BKNG', 'GE',
#        'AMZN', 'NFLX', 'MA', 'C', 'VZ', 'PYPL', 'GILD', 'F', 'BMY', 'KMI',
#        'SBUX', 'JNJ', 'CVS', 'NKE', 'TXN', 'TGT', 'BAC', 'ABT', 'RTN',
#        'GD', 'BLK', 'FB', 'SLB', 'WFC', 'FDX', 'CMCSA', 'AMGN', 'AAPL',
#        'MSFT', 'BIIB', 'DOW', 'V', 'COF', 'ABBV', 'MET', 'COP', 'WMT',
#        'UTX', 'PG', 'UNP', 'BK', 'NVDA', 'IBM', 'USB', 'MDLZ', 'MS',
#        'MRK'], dtype=object)

# %%
grp_opts(dft[dft.rom>0.25][dft.symbol=='COST'])
# Out:
# c:\users\kashir\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#    symbol expiration  strike right  dte  margin  undPrice  lot   undId  \
# 0    COST   20190607   235.0     P   18    7823   249.145  100  272997
# 1    COST   20190607   232.5     P   18    7823   249.145  100  272997
# 2    COST   20190607   230.0     P   18    7823   249.145  100  272997
# 3    COST   20190607   227.5     P   18    7823   249.145  100  272997
# 4    COST   20190607   225.0     P   18    7823   249.145  100  272997
# 5    COST   20190531   242.5     P   11    7823   249.145  100  272997
# 6    COST   20190531   240.0     P   11    7823   249.145  100  272997
# 7    COST   20190531   237.5     P   11    7823   249.145  100  272997
# 8    COST   20190531   235.0     P   11    7823   249.145  100  272997
# ...
