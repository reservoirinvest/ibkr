# %%
# SNP scanner and pickler

# STATUS: Completed
# Run-time: 1 hour and 31 mins before market opens

#***          Start ib_insync (run once)       *****
#___________________________________________________

from ib_insync import *
util.startLoop()
ib = IB().connect('127.0.0.1', 1300, clientId=2)

# %%
import os
from snplist import fspath, snp_list, get_opt
import datetime
import time

start = time.time()

# declaration
hrs = 3   # approximate time taken to get options for all scrips

# qualified list of stocks and index, with their contracts and chains
df_snplist = snp_list(ib)

# make the dfs from snplist
dfs = [df_snplist[df_snplist.symbol == s].reset_index(drop=True) for s in list(df_snplist.symbol.unique())]

# %%
# Take only pickle files. Remove directories and files starting with underscore (for underlyings)
fs = [f for f in os.listdir(fspath) if (f[-7:] == 'opt.pkl')] # list of opt pickle files

all_pickles = [fspath+f for f in os.listdir(fspath) if f.endswith('.pkl')]  # all pickled files
av_pkl_symbols = [f[:-8] for f in fs] # available pickle symbols

# %%
if fs: # if the file list is not empty
    
    # Get modified time, fail time and identify where the scrip has failed
    fsmod = {f: os.path.getmtime(fspath + '/' + f) for f in fs}
    failtime = max([v for k, v in fsmod.items()])
    failscrip = [k[:-4] for k, v in fsmod.items() if v == failtime][0]
    
    # now - porgram runtime
    floortime = (datetime.datetime.now() - datetime.timedelta(hours = hrs)).timestamp()
    
    if failtime < floortime:   # the pickles are old
#         [os.unlink(fn) for fn in all_pickles] # delete all the pickles
        [get_opt(ib, df) for df in dfs] # get options for all the symbols
    else:
        dfr = [df for df in dfs for sym in df.symbol.unique() if sym not in av_pkl_symbols] # pickle the remaining symbols

        [get_opt(ib, df) for df in dfr] # get options for all the symbols

else:  # there are no pickles
    [get_opt(ib, df) for df in dfs] # get options for all the symbols

end = time.time()

time_taken = end-start

m, s = divmod(time_taken, 60)
h, m = divmod(m, 60)

print("SNP build completed in {0:2.0f} hours : {1:2.0f} mins : {2:2.0f} seconds!".format(h, m, s))
ib.disconnect()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [BRKB] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-529950eee276> in <module>
#      15         dfr = [df for df in dfs for sym in df.symbol.unique() if sym not in av_pkl_symbols] # pickle the remaining symbols
#      16
# ---> 17         [get_opt(ib, df) for df in dfr] # get options for all the symbols
#      18
#      19 else:  # there are no pickles
#
# <ipython-input-13-529950eee276> in <listcomp>(.0)
#      15         dfr = [df for df in dfs for sym in df.symbol.unique() if sym not in av_pkl_symbols] # pickle the remaining symbols
#      16
# ---> 17         [get_opt(ib, df) for df in dfr] # get options for all the symbols
#      18
#      19 else:  # there are no pickles
#
# ~\Documents\ibkr\lib\snplist.py in get_opt(ib, df)
#     191     df['dte'] = [get_dte(e) for e in df.expiry]
#     192
# --> 193     df_tgt = filter_kxdte(df, df_ohlc)
#     194
#     195     # make the und_contracts
#
# ~\Documents\ibkr\lib\helper.py in filter_kxdte(df, df_ohlc)
#     133      if g == 'P'
#     134      else df_ohlc.set_index('symbol').loc[s][:max(floor_dte, d*3)].high.max()
# --> 135      for s, d, g in zip(df.symbol, df.dte, df.right)]
#     136
#     137     df = df[((df.right == 'P') & (df.strike < df.sfilt)) | \
#
# ~\Documents\ibkr\lib\helper.py in <listcomp>(.0)
#     133      if g == 'P'
#     134      else df_ohlc.set_index('symbol').loc[s][:max(floor_dte, d*3)].high.max()
# --> 135      for s, d, g in zip(df.symbol, df.dte, df.right)]
#     136
#     137     df = df[((df.right == 'P') & (df.strike < df.sfilt)) | \
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [BRKB] is not in the [index]'

# %%
df_snplist.loc[df_snplist.symbol == 'BRKB', :]
# Out:
#          expiry  strike symbol  \
# 27323  20190412   130.0   BRKB
# 27324  20190412   260.0   BRKB
# 27325  20190412   135.0   BRKB
# 27326  20190412   140.0   BRKB
# 27327  20190412   270.0   BRKB
# 27328  20190412   145.0   BRKB
# 27329  20190412   150.0   BRKB
# 27330  20190412   280.0   BRKB
# 27331  20190412   155.0   BRKB
# 27332  20190412   160.0   BRKB
# 27333  20190412   290.0   BRKB
# 27334  20190412   165.0   BRKB
# 27335  20190412   167.5   BRKB
# 27336  20190412   170.0   BRKB
# 27337  20190412   172.5   BRKB
# 27338  20190412   300.0   BRKB
# 27339  20190412   175.0   BRKB
# 27340  20190412   177.5   BRKB
# 27341  20190412   180.0   BRKB
# 27342  20190412   182.5   BRKB
# 27343  20190412   310.0   BRKB
# 27344  20190412   185.0   BRKB
# 27345  20190412   187.5   BRKB
# 27346  20190412   190.0   BRKB
# 27347  20190412   192.5   BRKB
# 27348  20190412   320.0   BRKB
# 27349  20190412   195.0   BRKB
# 27350  20190412   197.5   BRKB
# 27351  20190412   200.0   BRKB
# 27352  20190412   202.5   BRKB
# ...         ...     ...    ...
# 27865  20190426   187.5   BRKB
# 27866  20190426   190.0   BRKB
# 27867  20190426   192.5   BRKB
# 27868  20190426   320.0   BRKB
# 27869  20190426   195.0   BRKB
# 27870  20190426   197.5   BRKB
# 27871  20190426   200.0   BRKB
# 27872  20190426   202.5   BRKB
# 27873  20190426   205.0   BRKB
# 27874  20190426   207.5   BRKB
# 27875  20190426   210.0   BRKB
# 27876  20190426   212.5   BRKB
# 27877  20190426   215.0   BRKB
# 27878  20190426   217.5   BRKB
# 27879  20190426   220.0   BRKB
# 27880  20190426   222.5   BRKB
# 27881  20190426   225.0   BRKB
# 27882  20190426   227.5   BRKB
# 27883  20190426   100.0   BRKB
# 27884  20190426   230.0   BRKB
# 27885  20190426   232.5   BRKB
# 27886  20190426   105.0   BRKB
# 27887  20190426   235.0   BRKB
# 27888  20190426   237.5   BRKB
# 27889  20190426   110.0   BRKB
# 27890  20190426   240.0   BRKB
# 27891  20190426   115.0   BRKB
# 27892  20190426   120.0   BRKB
# 27893  20190426   250.0   BRKB
# 27894  20190426   125.0   BRKB
#
#                                             und_contract
# 27323  Stock(conId=72063691, symbol='BRK B', exchange...
# 27324  Stock(conId=72063691, symbol='BRK B', exchange...
# 27325  Stock(conId=72063691, symbol='BRK B', exchange...
# 27326  Stock(conId=72063691, symbol='BRK B', exchange...
# 27327  Stock(conId=72063691, symbol='BRK B', exchange...
# 27328  Stock(conId=72063691, symbol='BRK B', exchange...
# 27329  Stock(conId=72063691, symbol='BRK B', exchange...
# 27330  Stock(conId=72063691, symbol='BRK B', exchange...
# 27331  Stock(conId=72063691, symbol='BRK B', exchange...
# 27332  Stock(conId=72063691, symbol='BRK B', exchange...
# 27333  Stock(conId=72063691, symbol='BRK B', exchange...
# 27334  Stock(conId=72063691, symbol='BRK B', exchange...
# 27335  Stock(conId=72063691, symbol='BRK B', exchange...
# 27336  Stock(conId=72063691, symbol='BRK B', exchange...
# 27337  Stock(conId=72063691, symbol='BRK B', exchange...
# 27338  Stock(conId=72063691, symbol='BRK B', exchange...
# 27339  Stock(conId=72063691, symbol='BRK B', exchange...
# 27340  Stock(conId=72063691, symbol='BRK B', exchange...
# 27341  Stock(conId=72063691, symbol='BRK B', exchange...
# 27342  Stock(conId=72063691, symbol='BRK B', exchange...
# 27343  Stock(conId=72063691, symbol='BRK B', exchange...
# 27344  Stock(conId=72063691, symbol='BRK B', exchange...
# 27345  Stock(conId=72063691, symbol='BRK B', exchange...
# 27346  Stock(conId=72063691, symbol='BRK B', exchange...
# 27347  Stock(conId=72063691, symbol='BRK B', exchange...
# 27348  Stock(conId=72063691, symbol='BRK B', exchange...
# 27349  Stock(conId=72063691, symbol='BRK B', exchange...
# 27350  Stock(conId=72063691, symbol='BRK B', exchange...
# 27351  Stock(conId=72063691, symbol='BRK B', exchange...
# 27352  Stock(conId=72063691, symbol='BRK B', exchange...
# ...                                                  ...
# 27865  Stock(conId=72063691, symbol='BRK B', exchange...
# 27866  Stock(conId=72063691, symbol='BRK B', exchange...
# 27867  Stock(conId=72063691, symbol='BRK B', exchange...
# 27868  Stock(conId=72063691, symbol='BRK B', exchange...
# 27869  Stock(conId=72063691, symbol='BRK B', exchange...
# 27870  Stock(conId=72063691, symbol='BRK B', exchange...
# 27871  Stock(conId=72063691, symbol='BRK B', exchange...
# 27872  Stock(conId=72063691, symbol='BRK B', exchange...
# 27873  Stock(conId=72063691, symbol='BRK B', exchange...
# 27874  Stock(conId=72063691, symbol='BRK B', exchange...
# 27875  Stock(conId=72063691, symbol='BRK B', exchange...
# 27876  Stock(conId=72063691, symbol='BRK B', exchange...
# 27877  Stock(conId=72063691, symbol='BRK B', exchange...
# 27878  Stock(conId=72063691, symbol='BRK B', exchange...
# 27879  Stock(conId=72063691, symbol='BRK B', exchange...
# 27880  Stock(conId=72063691, symbol='BRK B', exchange...
# 27881  Stock(conId=72063691, symbol='BRK B', exchange...
# 27882  Stock(conId=72063691, symbol='BRK B', exchange...
# 27883  Stock(conId=72063691, symbol='BRK B', exchange...
# 27884  Stock(conId=72063691, symbol='BRK B', exchange...
# 27885  Stock(conId=72063691, symbol='BRK B', exchange...
# 27886  Stock(conId=72063691, symbol='BRK B', exchange...
# 27887  Stock(conId=72063691, symbol='BRK B', exchange...
# 27888  Stock(conId=72063691, symbol='BRK B', exchange...
# 27889  Stock(conId=72063691, symbol='BRK B', exchange...
# 27890  Stock(conId=72063691, symbol='BRK B', exchange...
# 27891  Stock(conId=72063691, symbol='BRK B', exchange...
# 27892  Stock(conId=72063691, symbol='BRK B', exchange...
# 27893  Stock(conId=72063691, symbol='BRK B', exchange...
# 27894  Stock(conId=72063691, symbol='BRK B', exchange...
#
# [208 rows x 4 columns]
