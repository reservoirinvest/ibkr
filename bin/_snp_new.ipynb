# %%
# x.py
from helper import *
from nse_func import *

# Do assignments
a = assign_var('snp')
for v in a:
    exec(v)

from ib_insync import *
util.startLoop()

ib =  get_connected('snp', 'live')

with open(logpath+'ztest.log', 'w'):
    pass # clear the run log

util.logToFile(logpath+'ztest.log')

# %%
# do_hist.py
def do_hist(ib, undId):
    '''Historize ohlc
    Args:
        (ib) as connection object
        (undId) as contractId for underlying symbol in int
    Returns:
        df_hist as dataframe
        pickles the dataframe by symbol name
    '''
    qc = ib.qualifyContracts(Contract(conId=int(undId)))[0]
    hist = ib.reqHistoricalData(contract=qc, endDateTime='', 
                                        durationStr='365 D', barSizeSetting='1 day',  
                                                    whatToShow='Trades', useRTH=True)
    df_hist = util.df(hist)
    df_hist = df_hist.assign(date=pd.to_datetime(df_hist.date, format='%Y-%m-%d'))
    df_hist.insert(loc=0, column='symbol', value=qc.symbol)
    df_hist = df_hist.sort_values('date', ascending = False).reset_index(drop=True)
    df_hist.to_pickle(fspath+'_'+qc.symbol+'_ohlc.pkl')
    return None

# %%
# Download cboe weeklies to a dataframe
dls = "http://www.cboe.com/publish/weelkysmf/weeklysmf.xls"

snp100 = list(pd.read_html('https://en.wikipedia.org/wiki/S%26P_100', 
                           header=0, match='Symbol')[0].loc[:, 'Symbol'])
snp100 = [s.replace('.', ' ') if '.' in s else s  for s in snp100] # without dot in symbol

# read from row no 11, dropna and reset index
df_cboe = pd.read_excel(dls, header=12, 
                        usecols=[0,2,3]).loc[11:, :]\
                        .dropna(axis=0)\
                        .reset_index(drop=True)

# remove column names white-spaces and remap to IBKR
df_cboe.columns = df_cboe.columns.str.replace(' ', '')

# remove '/' for IBKR
df_cboe.Ticker = df_cboe.Ticker.str.replace('/', ' ', regex=False)

# make symbols
symbols = {s for s in df_cboe.Ticker if s not in blacklist if s in snp100}

stocks = [Stock(symbol=s, exchange=exchange, currency='USD') for s in symbols]

stkblks = [stocks[i: i+blk] for i in range(0, len(stocks), blk)] # blocks of stocks

# qualify the contracts
contracts = [ib.qualifyContracts(*s) for s in stkblks]
contracts = [contract for subl in contracts for contract in subl]

# get the undPrices
tickers = ib.reqTickers(*contracts)
undPrices = {t.contract.symbol: t.marketPrice() for t in tickers} # {symbol: undPrice}

# make the dataframe of symbols
df_cs = util.df(contracts).loc[:, ['conId', 'symbol']]
df_cs = df_cs.rename({'conId': 'undId'}, axis='columns')

df_csul = df_cs.assign(undPrice=[round(undPrices[s],2) for s in df_cs.symbol], lot=100)

# get the chains
qundc = [v for k, v in qcs_dict.items()]

rawchains = {}
with tqdm(total=len(qundc), file=sys.stdout, unit=' symbol') as tqc:
    for q in qundc:
        tqc.set_description(f"SNP option chains frm IBKR for {q.symbol.ljust(9)}")
        rawchains.update({
            q: ib.reqSecDefOptParams(underlyingSymbol=q.symbol, 
                                      underlyingSecType='STK', 
                                      underlyingConId=q.conId, 
                                      futFopExchange='')})
        tqc.update(1)

chains = {k.symbol: j for k, v in rawchains.items() for j in v if j.exchange == exchange}

# integrate the strikes and expiries
exps = {k: v.expirations for k, v in chains.items()}
strikes = {k: v.strikes for k, v in chains.items()}

es = [list(product([k1], v1, v2)) for k1, v1 in exps.items() for k2, v2 in strikes.items() if k1 == k2]

df_es = pd.DataFrame([s for r in es for s in r], columns=['symbol', 'expiry', 'strike'])

# make the dataframe to be in between min and max dte
df_es = df_es.assign(dte=[get_dte(d) for d in df_es.expiry])
df_es = df_es[df_es.dte.between(mindte, maxdte)].reset_index(drop=True)

# make the chains dataframe
df_chains = pd.merge(df_csul, df_es)

# put the rights
df_chains = pd.concat([df_chains.assign(right='P'), df_chains.assign(right='C')]).reset_index(drop=True)

# make the chains small
mask = (df_chains.right == 'P') & (df_chains.strike < df_chains.undPrice) | \
       (df_chains.right == 'C') & (df_chains.strike > df_chains.undPrice)
df_chains = df_chains[mask].reset_index(drop=True)

# %%
#... Historize
#_____________

qual_unds = list(qcs_dict.values()) # qualified underlyings

# historize individual underlyings
hists = [] # initialize a list of underlying histories. Will be empty.
with tqdm(total=len(qual_unds), file=sys.stdout, unit=' symbol') as tqh:
    for q in qual_unds:
        tqh.set_description(f"Getting OHLC hist frm IBKR for {q.symbol.ljust(9)}")
        hists.append(catch(lambda: do_hist(ib, q.conId)))  # makes ohlc.pkl
        tqh.update(1)

# Capture the ohlc pickles
ohlc_pkls = [f for f in listdir(fspath) if (f[-8:] == 'ohlc.pkl')]
df_ohlcs = pd.concat([pd.read_pickle(fspath+o) for o in ohlc_pkls]).reset_index(drop=True)

# put stdev in ohlc and consolidate
df_ohlcs = df_ohlcs.assign(stDev=df_ohlcs.groupby('symbol').close.transform(lambda x: x.expanding(1).std(ddof=0)))
df_ohlcs.to_pickle(fspath+'ohlcs.pkl')
# Out:
# Getting OHLC hist frm IBKR for CHTR     : 100%|███████████████████████████████████| 91/91 [03:04<00:00,  1.45s/ symbol]

# %%
# generate std dataframe
df = df_ohlcs[['symbol', 'stDev']]  # lookup dataframe
df = df.assign(dte=df.groupby('symbol').cumcount()) # get the cumulative count for location as dte
df.set_index(['symbol', 'dte'])

df1 = df_chains[['symbol', 'dte']]  # data to be looked at
df2 = df1.drop_duplicates()  # remove duplicates

df_std = df2.set_index(['symbol', 'dte']).join(df.set_index(['symbol', 'dte']))

# join to get std in chains
df_chainstd = df_chains.set_index(['symbol', 'dte']).join(df_std).reset_index()

# %%
# eliminate puts and calls out of threshold
put_mask = (df_chainstd.strike < (df_chainstd.undPrice-(df_chainstd.stDev*putstdmult)))
df_puts = df_chainstd[put_mask]

call_mask = (df_chainstd.strike > (df_chainstd.undPrice+(df_chainstd.stDev*callstdmult)))
df_calls = df_chainstd[call_mask]

# %%
df_opts = pd.concat([df_puts, df_calls]).reset_index(drop=True)

# %%
# collect the option contracts
optcons = [Option(i.symbol, i.expiry, i.strike, i.right, 'SMART') for i in df_opts[['symbol', 'expiry', 'strike', 'right']].itertuples()]

# dice them into blocks
optblks = [optcons[i: i+blk] for i in range(0, len(optcons), blk)]

# qualify the contracts in blocks
cblks = []
with tqdm(total=len(optblks), file=sys.stdout, unit=' symbol') as tqo:
    for q in optblks:
        tqo.set_description(f"Qualifying chains {q[0].symbol.ljust(9)} to {q[len(q)-1].symbol.ljust(9)}")
        cblks.append([ib.qualifyContracts(s) for s in q])
        tqo.update(1)

opts = [z for x in cblks for z in x]

# %%
[z for x in cblks for z in x if z]
# Out:
# [[Option(conId=367618730, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=130.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00130000', tradingClass='AAPL')],
#  [Option(conId=367618737, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=131.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00131000', tradingClass='AAPL')],
#  [Option(conId=367618740, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=132.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00132000', tradingClass='AAPL')],
#  [Option(conId=367618750, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=133.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00133000', tradingClass='AAPL')],
#  [Option(conId=367618761, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=134.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00134000', tradingClass='AAPL')],
#  [Option(conId=365946235, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=135.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00135000', tradingClass='AAPL')],
#  [Option(conId=367618770, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=136.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00136000', tradingClass='AAPL')],
#  [Option(conId=367618776, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=137.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00137000', tradingClass='AAPL')],
#  [Option(conId=367618781, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=138.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00138000', tradingClass='AAPL')],
#  [Option(conId=367618785, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=139.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00139000', tradingClass='AAPL')],
#  [Option(conId=365946241, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=140.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00140000', tradingClass='AAPL')],
#  [Option(conId=367618800, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=141.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00141000', tradingClass='AAPL')],
#  [Option(conId=367618815, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=142.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00142000', tradingClass='AAPL')],
#  [Option(conId=367618820, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=143.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00143000', tradingClass='AAPL')],
#  [Option(conId=367618832, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=144.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00144000', tradingClass='AAPL')],
#  [Option(conId=365946244, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=145.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00145000', tradingClass='AAPL')],
#  [Option(conId=367618847, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=146.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00146000', tradingClass='AAPL')],
#  [Option(conId=367618866, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=147.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00147000', tradingClass='AAPL')],
#  [Option(conId=367618872, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=148.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00148000', tradingClass='AAPL')],
#  [Option(conId=367618895, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=149.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00149000', tradingClass='AAPL')],
#  [Option(conId=365341302, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=150.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00150000', tradingClass='AAPL')],
#  [Option(conId=367618907, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=152.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00152500', tradingClass='AAPL')],
#  [Option(conId=365341305, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00155000', tradingClass='AAPL')],
#  [Option(conId=367618914, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=157.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00157500', tradingClass='AAPL')],
#  [Option(conId=365341315, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=160.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00160000', tradingClass='AAPL')],
#  [Option(conId=367618919, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=162.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00162500', tradingClass='AAPL')],
#  [Option(conId=365341324, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00165000', tradingClass='AAPL')],
#  [Option(conId=368795073, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=167.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00167500', tradingClass='AAPL')],
#  [Option(conId=365341335, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00170000', tradingClass='AAPL')],
#  [Option(conId=368795088, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=172.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00172500', tradingClass='AAPL')],
#  [Option(conId=365341348, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=175.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00175000', tradingClass='AAPL')],
#  [Option(conId=365341360, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=177.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00177500', tradingClass='AAPL')],
#  [Option(conId=365341365, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=180.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00180000', tradingClass='AAPL')],
#  [Option(conId=365341384, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=182.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00182500', tradingClass='AAPL')],
#  [Option(conId=365341389, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=185.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00185000', tradingClass='AAPL')],
#  [Option(conId=365341398, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=187.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00187500', tradingClass='AAPL')],
#  [Option(conId=365341404, symbol='AAPL', lastTradeDateOrContractMonth='20190628', strike=190.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190628P00190000', tradingClass='AAPL')],
#  [Option(conId=367739420, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=125.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00125000', tradingClass='AAPL')],
#  [Option(conId=367739429, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=130.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00130000', tradingClass='AAPL')],
#  [Option(conId=367739451, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=135.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00135000', tradingClass='AAPL')],
#  [Option(conId=367739465, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=140.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00140000', tradingClass='AAPL')],
#  [Option(conId=367739480, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=145.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00145000', tradingClass='AAPL')],
#  [Option(conId=370055593, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=149.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00149000', tradingClass='AAPL')],
#  [Option(conId=367739499, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=150.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00150000', tradingClass='AAPL')],
#  [Option(conId=368795140, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=152.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00152500', tradingClass='AAPL')],
#  [Option(conId=367739519, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00155000', tradingClass='AAPL')],
#  [Option(conId=367739525, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=157.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00157500', tradingClass='AAPL')],
#  [Option(conId=367739550, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=160.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00160000', tradingClass='AAPL')],
#  [Option(conId=367739554, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=162.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00162500', tradingClass='AAPL')],
#  [Option(conId=367739574, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00165000', tradingClass='AAPL')],
#  [Option(conId=367739577, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=167.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00167500', tradingClass='AAPL')],
#  [Option(conId=367739588, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00170000', tradingClass='AAPL')],
#  [Option(conId=367739600, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=172.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00172500', tradingClass='AAPL')],
#  [Option(conId=367739615, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=175.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00175000', tradingClass='AAPL')],
#  [Option(conId=367739625, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=177.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00177500', tradingClass='AAPL')],
#  [Option(conId=367739634, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=180.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00180000', tradingClass='AAPL')],
#  [Option(conId=367739645, symbol='AAPL', lastTradeDateOrContractMonth='20190705', strike=182.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190705P00182500', tradingClass='AAPL')],
#  [Option(conId=368795651, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=125.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00125000', tradingClass='AAPL')],
#  [Option(conId=368795660, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=130.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00130000', tradingClass='AAPL')],
#  [Option(conId=368795671, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=135.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00135000', tradingClass='AAPL')],
#  [Option(conId=368795672, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=140.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00140000', tradingClass='AAPL')],
#  [Option(conId=368795684, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=145.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00145000', tradingClass='AAPL')],
#  [Option(conId=370055633, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=149.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00149000', tradingClass='AAPL')],
#  [Option(conId=368795696, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=150.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00150000', tradingClass='AAPL')],
#  [Option(conId=368795711, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=152.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00152500', tradingClass='AAPL')],
#  [Option(conId=368795719, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00155000', tradingClass='AAPL')],
#  [Option(conId=368795731, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=157.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00157500', tradingClass='AAPL')],
#  [Option(conId=368795737, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=160.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00160000', tradingClass='AAPL')],
#  [Option(conId=368795749, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=162.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00162500', tradingClass='AAPL')],
#  [Option(conId=368795771, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00165000', tradingClass='AAPL')],
#  [Option(conId=368795780, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=167.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00167500', tradingClass='AAPL')],
#  [Option(conId=368795790, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00170000', tradingClass='AAPL')],
#  [Option(conId=368795797, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=172.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00172500', tradingClass='AAPL')],
#  [Option(conId=368795811, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=175.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00175000', tradingClass='AAPL')],
#  [Option(conId=368795814, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=177.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00177500', tradingClass='AAPL')],
#  [Option(conId=368795817, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=180.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00180000', tradingClass='AAPL')],
#  [Option(conId=368795832, symbol='AAPL', lastTradeDateOrContractMonth='20190712', strike=182.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190712P00182500', tradingClass='AAPL')],
#  [Option(conId=348028875, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=80.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00080000', tradingClass='AAPL')],
#  [Option(conId=346458343, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=85.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00085000', tradingClass='AAPL')],
#  [Option(conId=342191227, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=90.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00090000', tradingClass='AAPL')],
#  [Option(conId=342191230, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=95.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00095000', tradingClass='AAPL')],
#  [Option(conId=342190622, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=100.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00100000', tradingClass='AAPL')],
#  [Option(conId=342190637, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=105.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00105000', tradingClass='AAPL')],
#  [Option(conId=342190649, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=110.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00110000', tradingClass='AAPL')],
#  [Option(conId=342190667, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=115.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00115000', tradingClass='AAPL')],
#  [Option(conId=342190682, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=120.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00120000', tradingClass='AAPL')],
#  [Option(conId=342190700, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=125.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00125000', tradingClass='AAPL')],
#  [Option(conId=342190722, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=130.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00130000', tradingClass='AAPL')],
#  [Option(conId=342190767, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=135.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00135000', tradingClass='AAPL')],
#  [Option(conId=342190779, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=140.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00140000', tradingClass='AAPL')],
#  [Option(conId=342190793, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=145.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00145000', tradingClass='AAPL')],
#  [Option(conId=342190808, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=150.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00150000', tradingClass='AAPL')],
#  [Option(conId=342190830, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00155000', tradingClass='AAPL')],
#  [Option(conId=342190859, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=160.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00160000', tradingClass='AAPL')],
#  [Option(conId=342190879, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00165000', tradingClass='AAPL')],
#  [Option(conId=342190892, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00170000', tradingClass='AAPL')],
#  [Option(conId=342190909, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=175.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00175000', tradingClass='AAPL')],
#  [Option(conId=342190922, symbol='AAPL', lastTradeDateOrContractMonth='20190719', strike=180.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190719P00180000', tradingClass='AAPL')],
#  [Option(conId=370056020, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=149.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00149000', tradingClass='AAPL')],
#  [Option(conId=370056039, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=150.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00150000', tradingClass='AAPL')],
#  [Option(conId=370056045, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=152.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00152500', tradingClass='AAPL')],
#  [Option(conId=370056070, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00155000', tradingClass='AAPL')],
#  [Option(conId=370056076, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=157.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00157500', tradingClass='AAPL')],
#  [Option(conId=370056088, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=160.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00160000', tradingClass='AAPL')],
#  [Option(conId=370056100, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=162.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00162500', tradingClass='AAPL')],
#  [Option(conId=370056110, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00165000', tradingClass='AAPL')],
#  [Option(conId=370056117, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=167.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00167500', tradingClass='AAPL')],
#  [Option(conId=370056130, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00170000', tradingClass='AAPL')],
#  [Option(conId=370056147, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=172.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00172500', tradingClass='AAPL')],
#  [Option(conId=370056153, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=175.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00175000', tradingClass='AAPL')],
#  [Option(conId=370056175, symbol='AAPL', lastTradeDateOrContractMonth='20190726', strike=177.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190726P00177500', tradingClass='AAPL')],
#  [Option(conId=370920015, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=150.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00150000', tradingClass='AAPL')],
#  [Option(conId=370920017, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=155.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00155000', tradingClass='AAPL')],
#  [Option(conId=370920020, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=160.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00160000', tradingClass='AAPL')],
#  [Option(conId=370920027, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=165.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00165000', tradingClass='AAPL')],
#  [Option(conId=370920030, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=167.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00167500', tradingClass='AAPL')],
#  [Option(conId=370920034, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=170.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00170000', tradingClass='AAPL')],
#  [Option(conId=370920039, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=172.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00172500', tradingClass='AAPL')],
#  [Option(conId=370920040, symbol='AAPL', lastTradeDateOrContractMonth='20190802', strike=175.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='AAPL  190802P00175000', tradingClass='AAPL')],
#  [Option(conId=365639500, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=60.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00060000', tradingClass='ABBV')],
#  [Option(conId=365639512, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=65.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00065000', tradingClass='ABBV')],
#  [Option(conId=371193980, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=67.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00067000', tradingClass='ABBV')],
#  [Option(conId=371193977, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=67.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00067500', tradingClass='ABBV')],
#  [Option(conId=371193990, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=68.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00068000', tradingClass='ABBV')],
#  [Option(conId=371193987, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=68.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00068500', tradingClass='ABBV')],
#  [Option(conId=371193996, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=69.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00069000', tradingClass='ABBV')],
#  [Option(conId=371193993, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=69.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00069500', tradingClass='ABBV')],
#  [Option(conId=365639521, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=70.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00070000', tradingClass='ABBV')],
#  [Option(conId=371194002, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=70.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00070500', tradingClass='ABBV')],
#  [Option(conId=368794559, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=71.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00071000', tradingClass='ABBV')],
#  [Option(conId=365340464, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=71.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00071500', tradingClass='ABBV')],
#  [Option(conId=365340479, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=72.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00072000', tradingClass='ABBV')],
#  [Option(conId=365340474, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=72.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00072500', tradingClass='ABBV')],
#  [Option(conId=365340493, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=73.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00073000', tradingClass='ABBV')],
#  [Option(conId=365340487, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=73.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00073500', tradingClass='ABBV')],
#  [Option(conId=365340508, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=74.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00074000', tradingClass='ABBV')],
#  [Option(conId=365340505, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=74.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00074500', tradingClass='ABBV')],
#  [Option(conId=365340529, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=75.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00075000', tradingClass='ABBV')],
#  [Option(conId=365340522, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=75.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00075500', tradingClass='ABBV')],
#  [Option(conId=365340545, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=76.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00076000', tradingClass='ABBV')],
#  [Option(conId=365340539, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=76.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00076500', tradingClass='ABBV')],
#  [Option(conId=365340582, symbol='ABBV', lastTradeDateOrContractMonth='20190628', strike=77.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190628P00077000', tradingClass='ABBV')],
#  [Option(conId=369281854, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=60.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00060000', tradingClass='ABBV')],
#  [Option(conId=368325523, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=65.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00065000', tradingClass='ABBV')],
#  [Option(conId=368325556, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=70.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00070000', tradingClass='ABBV')],
#  [Option(conId=368794607, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=71.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00071000', tradingClass='ABBV')],
#  [Option(conId=368794592, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=71.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00071500', tradingClass='ABBV')],
#  [Option(conId=368794612, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=72.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00072000', tradingClass='ABBV')],
#  [Option(conId=368794609, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=72.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00072500', tradingClass='ABBV')],
#  [Option(conId=367739322, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=73.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00073500', tradingClass='ABBV')],
#  [Option(conId=367739341, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=74.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00074000', tradingClass='ABBV')],
#  [Option(conId=367739327, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=74.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00074500', tradingClass='ABBV')],
#  [Option(conId=367739370, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=75.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00075000', tradingClass='ABBV')],
#  [Option(conId=367739356, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=75.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00075500', tradingClass='ABBV')],
#  [Option(conId=367739414, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=76.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00076000', tradingClass='ABBV')],
#  [Option(conId=367739394, symbol='ABBV', lastTradeDateOrContractMonth='20190705', strike=76.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190705P00076500', tradingClass='ABBV')],
#  [Option(conId=369281925, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=60.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00060000', tradingClass='ABBV')],
#  [Option(conId=369281950, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=65.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00065000', tradingClass='ABBV')],
#  [Option(conId=369281974, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=70.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00070000', tradingClass='ABBV')],
#  [Option(conId=368794850, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=71.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00071000', tradingClass='ABBV')],
#  [Option(conId=368794843, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=71.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00071500', tradingClass='ABBV')],
#  [Option(conId=368794873, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=72.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00072000', tradingClass='ABBV')],
#  [Option(conId=368794867, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=72.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00072500', tradingClass='ABBV')],
#  [Option(conId=368794888, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=73.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00073000', tradingClass='ABBV')],
#  [Option(conId=368794882, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=73.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00073500', tradingClass='ABBV')],
#  [Option(conId=368794905, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=74.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00074000', tradingClass='ABBV')],
#  [Option(conId=368794893, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=74.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00074500', tradingClass='ABBV')],
#  [Option(conId=368794929, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=75.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00075000', tradingClass='ABBV')],
#  [Option(conId=368794912, symbol='ABBV', lastTradeDateOrContractMonth='20190712', strike=75.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190712P00075500', tradingClass='ABBV')],
#  [Option(conId=366666911, symbol='ABBV', lastTradeDateOrContractMonth='20190719', strike=60.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190719P00060000', tradingClass='ABBV')],
#  [Option(conId=366666918, symbol='ABBV', lastTradeDateOrContractMonth='20190719', strike=65.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190719P00065000', tradingClass='ABBV')],
#  [Option(conId=369282010, symbol='ABBV', lastTradeDateOrContractMonth='20190719', strike=67.5, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='ABBV  190719P00067500', tradingClass='ABBV')]]

# %%
df_mega.to_pickle(fspath+'base.pickle')
util.logging.info('_________________SNP BASE BUILD COMPLETE_________________________')

# %%
# get the max fall and rise
df_frs = df_mega.drop('strike', 1).drop_duplicates() # for fall rise std

mfrs = [((s, d) + get_maxfallrisestd(ib=ib, c=c, dte=d, tradingdays=tradingdays, durmult=durmult)) for s, c, d in zip(df_frs.symbol, df_frs.contract, df_frs.dte)]

df_mfrs = pd.DataFrame(mfrs, columns=['symbol', 'dte', 'lo52', 'hi52', 'Fall', 'Rise', 'Std'])

df_mega = df_mega.set_index(['symbol', 'dte']).join(df_mfrs.set_index(['symbol', 'dte'])).reset_index()
df_mega['loStd'] = df_mega.undPrice - df_mega['Std'].multiply(putstdmult)
df_mega['hiStd'] = df_mega.undPrice + df_mega['Std'].multiply(callstdmult)

# flter puts and calls by standard deviation
df_puts = df_mega[df_mega.strike < df_mega.loStd]
df_calls = df_mega[df_mega.strike > df_mega.hiStd]

df_puts = df_puts.assign(right='P')
df_calls = df_calls.assign(right='C')

# qualify the options
df = pd.concat([df_puts, df_calls]).reset_index(drop=True).drop('contract', axis=1)

# qualify the option contracts
optipl = [Option(s, e, k, r, exchange) for s, e, k, r in zip(df.symbol, df.expiration, df.strike, df.right)]
optblks = [optipl[i: i+blk] for i in range(0, len(optipl), blk)] # blocks of optipl
cblks = [ib.qualifyContracts(*s) for s in optblks]
contracts = [z for x in cblks for z in x]

# prepare the qualified options dataframe
dfq = util.df(contracts).iloc[:, 1:6]
dfq.columns=['optId', 'symbol', 'expiration', 'strike', 'right'] # rename columns
dfq = dfq.set_index(['symbol', 'expiration', 'strike', 'right']) # set index

# join the qualified options with main dataframe. Remove those without conId
df_opt = df.set_index(['symbol', 'expiration', 'strike', 'right']).join(dfq).dropna()

# convert optId to int for price and margin
df_opt = df_opt.assign(optId=df_opt.optId.astype('int32'))

# get the prices
opt_tickers = ib.reqTickers(*contracts)
optPrices = {t.contract.conId: t.marketPrice() for t in opt_tickers}

df_opt = df_opt.assign(optPrice=df_opt.optId.map(optPrices))
df_opt = df_opt[~(df_opt.optPrice <= 0)].reset_index() # remove options without a price

#... get the margins
# {conId: contract} dictionary
c_dict = {c.conId: c for c in contracts if c.conId in list(df_opt.optId)}
orders = [Order(action='SELL', orderType='MKT', totalQuantity=1, whatIf=True)]*len(c_dict)

# get the margins
margins = [float(catch(lambda: (ib.whatIfOrder(c, o).initMarginChange))) for c, o in zip(c_dict.values(), orders)]

df_opt = df_opt.assign(optMargin = margins)
df_opt = df_opt[df_opt.optMargin < 1e7] # remove options with very large margins

# get the rom
df_opt = df_opt.assign(rom=df_opt.optPrice*df_opt.lot/df_opt.optMargin*365/df_opt.dte).sort_values('rom', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-47976e352e6a> in <module>
#       5 df_frs = df_mega.drop('strike', 1).drop_duplicates() # for fall rise std
#       6
# ----> 7 mfrs = [((s, d) + get_maxfallrisestd(ib=ib, c=c, dte=d, tradingdays=tradingdays, durmult=durmult)) for s, c, d in zip(df_frs.symbol, df_frs.contract, df_frs.dte)]
#       8
#       9 df_mfrs = pd.DataFrame(mfrs, columns=['symbol', 'dte', 'lo52', 'hi52', 'Fall', 'Rise', 'Std'])
#
# <ipython-input-11-47976e352e6a> in <listcomp>(.0)
#       5 df_frs = df_mega.drop('strike', 1).drop_duplicates() # for fall rise std
#       6
# ----> 7 mfrs = [((s, d) + get_maxfallrisestd(ib=ib, c=c, dte=d, tradingdays=tradingdays, durmult=durmult)) for s, c, d in zip(df_frs.symbol, df_frs.contract, df_frs.dte)]
#       8
#       9 df_mfrs = pd.DataFrame(mfrs, columns=['symbol', 'dte', 'lo52', 'hi52', 'Fall', 'Rise', 'Std'])
#
# NameError: name 'get_maxfallrisestd' is not defined
