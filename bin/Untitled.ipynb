# %%
# -*- coding: utf-8 -*-
import json

jupfile = 'snplist.ipynb'

with open('snplist.ipynb') as data_file:
    code = json.load(data_file)

# %%
for cell in code['cells']:
    if cell['cell_type'] == 'code':
        for line in cell['source']:
            print(line, end='')
        print('\n')
# Out:
# from ib_insync import *
# util.startLoop()
# ib = IB().connect('127.0.0.1', 1300, clientId=20) # For snp - Kashi
#
# import pandas as pd
# import numpy as np
# from itertools import product, repeat
# from ib_insync import Stock, Index, util, Order, Option
# import datetime
# from collections import OrderedDict
#
# from helper import get_div_tick, get_dte, filter_kxdte, get_bsm, catch
# from ohlc import get_ohlc
#
# # declarations
#
# exchange = 'SMART'
# currency = 'USD'
# fspath = '../data/snp/'
#
# maxdte = 70  # max expiry date for options
# mindte = 20  # min expiry date for options
# blks = 50
# tradingdays = 252
#
# #... make the rates
# #__________________
#
# rate_url = 'https://www.treasury.gov/resource-center/data-chart-center/interest-rates/pages/textview.aspx?data=yield'
# df_rate = pd.read_html(rate_url)[1]
# df_rate.columns  = df_rate.iloc[0] # Set the first row as header
# df_rate = df_rate.drop(0,0) # Drop the first row
# ...

# %%
code
# Out:
# {'cells': [{'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {},
#    'outputs': [],
#    'source': ['from ib_insync import *\n',
#     'util.startLoop()\n',
#     "ib = IB().connect('127.0.0.1', 1300, clientId=20) # For snp - Kashi"]},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {},
#    'outputs': [],
#    'source': ['import pandas as pd\n',
#     'import numpy as np\n',
#     'from itertools import product, repeat\n',
#     'from ib_insync import Stock, Index, util, Order, Option\n',
#     'import datetime\n',
#     'from collections import OrderedDict\n',
#     '\n',
#     'from helper import get_div_tick, get_dte, filter_kxdte, get_bsm, catch\n',
#     'from ohlc import get_ohlc\n',
#     '\n',
#     '# declarations\n',
#     '\n',
#     "exchange = 'SMART'\n",
#     "currency = 'USD'\n",
#     "fspath = '../data/snp/'\n",
#     '\n',
#     'maxdte = 70  # max expiry date for options\n',
# ...
