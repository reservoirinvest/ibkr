# %%
# %%time

import pandas as pd

from math import isnan

exchange = 'NSE'

#... build the symbols
#______________________

tp = pd.read_html('https://www.tradeplusonline.com/Equity-Futures-Margin-Calculator.aspx')

df_tp = tp[1][2:].iloc[:, :-1]
df_tp = df_tp.iloc[:, [0,1,5]]
df_tp.columns=['nseSymbol', 'lot', 'margin']

cols = df_tp.columns.drop('nseSymbol')
df_tp[cols] = df_tp[cols].apply(pd.to_numeric, errors='coerce') # convert lot and margin to numeric

df_slm = df_tp.copy()

# Truncate to 9 characters for ibSymbol
df_slm['ibSymbol'] = df_slm.nseSymbol.str.slice(0,9)

# nseSymbol to ibSymbol dictionary for conversion
ntoi = {'M&M': 'MM', 'M&MFIN': 'MMFIN', 'L&TFH': 'LTFH', 'NIFTY': 'NIFTY50'}

# remap ibSymbol, based on the dictionary
df_slm.ibSymbol = df_slm.ibSymbol.replace(ntoi)

# separate indexes and equities, eliminate discards from df_slm
indexes = ['NIFTY50', 'BANKNIFTY']
discards = ['NIFTYMID5', 'NIFTYIT', 'LUPIN']
equities = sorted([s for s in df_slm.ibSymbol if s not in indexes+discards])

symbols = equities+indexes
exchange = 'NSE'

from ib_insync import *
util.startLoop()
ib = IB()

with ib.connect('127.0.0.1', 3000, clientId=13): # For nse - Kavi:
    cs = [Stock(s, exchange) if s in equities else Index(s, exchange) for s in symbols]
    qcs = ib.qualifyContracts(*cs) # qualified underlyings
# Out:
# Started to throttle requests
# Stopped to throttle requests
# Wall time: 17.9 s

# %%
with ib.connect('127.0.0.1', 3000, clientId=13): # For nse - Kavi:
    mdata = []
    for i in range(0, len(qcs), 100):
        for q in qcs[i:i+100]:
            mdata.append(ib.reqMktData(contract=q, genericTickList='456', snapshot=False, regulatorySnapshot=False))
# Out:
# Started to throttle requests

# %%
mdata
# Out:
# [Ticker(contract=Stock(conId=44652144, symbol='ACC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ACC', tradingClass='ACC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986798, symbol='ADANIENT', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ADANIENT', tradingClass='ADANIENT'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=79403918, symbol='ADANIPORT', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ADANIPORTS', tradingClass='ADANIPORT'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=70299711, symbol='ADANIPOWE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ADANIPOWER', tradingClass='ADANIPOWE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=187395649, symbol='AJANTPHAR', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='AJANTPHARM', tradingClass='AJANTPHAR'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56988229, symbol='ALBK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ALBK', tradingClass='ALBK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=113744943, symbol='AMARAJABA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='AMARAJABAT', tradingClass='AMARAJABA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652129, symbol='AMBUJACEM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='AMBUJACEM', tradingClass='AMBUJACEM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=78607402, symbol='APOLLOHOS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='APOLLOHOSP', tradingClass='APOLLOHOS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56988336, symbol='APOLLOTYR', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='APOLLOTYRE', tradingClass='APOLLOTYR'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56988374, symbol='ARVIND', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ARVIND', tradingClass='ARVIND'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56988221, symbol='ASHOKLEY', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ASHOKLEY', tradingClass='ASHOKLEY'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=132214022, symbol='ASIANPAIN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ASIANPAINT', tradingClass='ASIANPAIN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=83937139, symbol='AUROPHARM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='AUROPHARMA', tradingClass='AUROPHARM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=162089869, symbol='AXISBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='AXISBANK', tradingClass='AXISBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987980, symbol='BAJAJ-AUT', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='BAJAJ-AUTO', tradingClass='BAJAJ-AUT'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987991, symbol='BAJAJFINS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='BAJAJFINSV', tradingClass='BAJAJFINS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=247227232, symbol='BAJFINANC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='BAJFINANCE', tradingClass='BAJFINANC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId
'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=174961888, symbol='GODFRYPHL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='GODFRYPHLP', tradingClass='GODFRYPHL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986171, symbol='GODREJCP', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='GODREJCP', tradingClass='GODREJCP'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986182, symbol='GODREJIND', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='GODREJIND', tradingClass='GODREJIND'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=250071842, symbol='GRASIM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='GRASIM', tradingClass='GRASIM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=113787164, symbol='GSFC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='GSFC', tradingClass='GSFC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=164667099, symbol='HAVELLS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HAVELLS', tradingClass='HAVELLS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652094, symbol='HCLTECH', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HCLTECH', tradingClass='HCLTECH'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=77975259, symbol='HDFC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HDFC', tradingClass='HDFC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=90825534, symbol='HDFCBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HDFCBANK', tradingClass='HDFCBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652149, symbol='HEROMOTOC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HEROMOTOCO', tradingClass='HEROMOTOC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983874, symbol='HEXAWARE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HEXAWARE', tradingClass='HEXAWARE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652119, symbol='HINDALCO', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HINDALCO', tradingClass='HINDALCO'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652194, symbol='HINDPETRO', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HINDPETRO', tradingClass='HINDPETRO'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652060, symbol='HINDUNILV', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HINDUNILVR', tradingClass='HINDUNILV'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=84948060, symbol='HINDZINC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='HINDZINC', tradingClass='HINDZINC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=125585152, symbol='IBULHSGFI', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IBULHSGFIN', tradingClass='IBULHSGFI'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=175596029, symbol='ICICIBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ICICIBANK', tradingClass='ICICIBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=249453974, symbol='ICICIPRUL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ICICIPRULI', tradingClass='ICICIPRUL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985599, symbol='IDBI', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IDBI', tradingClass='IDBI'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=50486121, symbol='IDEA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IDEA', tradingClass='IDEA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985600, symbol='IDFC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IDFC', tradingClass='IDFC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=209462790, symbol='IDFCFIRST', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IDFCFIRSTB', tradingClass='IDFCFIRST'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985620, symbol='IFCI', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IFCI', tradingClass='IFCI'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=294350643, symbol='IGL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IGL', tradingClass='IGL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985582, symbol='INDIACEM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='INDIACEM', tradingClass='INDIACEM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985685, symbol='INDIANB', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='INDIANB', tradingClass='INDIANB'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=212126639, symbol='INDIGO', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='INDIGO', tradingClass='INDIGO'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985651, symbol='INDUSINDB', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='INDUSINDBK', tradingClass='INDUSINDB'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=287232453, symbol='INFIBEAM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='INFIBEAM', tradingClass='INFIBEAM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=119707173, symbol='INFRATEL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='INFRATEL', tradingClass='INFRATEL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652017, symbol='INFY', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='INFY', tradingClass='INFY'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985747, symbol='IOC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IOC', tradingClass='IOC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985795, symbol='IRB', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='IRB', tradingClass='IRB'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652040, symbol='ITC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ITC', tradingClass='ITC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984184, symbol='JETAIRWAY', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='JETAIRWAYS', tradingClass='JETAIRWAY'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984268, symbol='JINDALSTE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='JINDALSTEL', tradingClass='JINDALSTE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=80423707, symbol='JISLJALEQ', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='JISLJALEQS', tradingClass='JISLJALEQ'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984254, symbol='JPASSOCIA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='JPASSOCIAT', tradingClass='JPASSOCIA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=261024709, symbol='JSWSTEEL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='JSWSTEEL', tradingClass='JSWSTEEL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=72513009, symbol='JUBLFOOD', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='JUBLFOOD', tradingClass='JUBLFOOD'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=128882870, symbol='JUSTDIAL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='JUSTDIAL', tradingClass='JUSTDIAL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=250071823, symbol='KAJARIACE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='KAJARIACER', tradingClass='KAJARIACE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=78743661, symbol='KOTAKBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='KOTAKBANK', tradingClass='KOTAKBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=143038370, symbol='KSCL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='KSCL', tradingClass='KSCL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984959, symbol='KTKBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='KTKBANK', tradingClass='KTKBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=82450876, symbol='LICHSGFIN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='LICHSGFIN', tradingClass='LICHSGFIN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652051, symbol='LT', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='LT', tradingClass='LT'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=92679222, symbol='LTFH', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='L&TFH', tradingClass='LTFH'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=74960455, symbol='MANAPPURA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MANAPPURAM', tradingClass='MANAPPURA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987333, symbol='MARICO', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MARICO', tradingClass='MARICO'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652108, symbol='MARUTI', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MARUTI', tradingClass='MARUTI'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=321318372, symbol='MCDOWELL-', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MCDOWELL-N', tradingClass='MCDOWELL-'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=103853702, symbol='MCX', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MCX', tradingClass='MCX'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987139, symbol='MFSL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MFSL', tradingClass='MFSL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=239032762, symbol='MGL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MGL', tradingClass='MGL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987628, symbol='MINDTREE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MINDTREE', tradingClass='MINDTREE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=73894413, symbol='MM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='M&M', tradingClass='MM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=122139383, symbol='MMFIN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='M&MFIN', tradingClass='MMFIN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987580, symbol='MOTHERSUM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MOTHERSUMI', tradingClass='MOTHERSUM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987338, symbol='MRF', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MRF', tradingClass='MRF'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987368, symbol='MRPL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MRPL', tradingClass='MRPL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=87790418, symbol='MUTHOOTFI', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='MUTHOOTFIN', tradingClass='MUTHOOTFI'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=85433002, symbol='NATIONALU', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NATIONALUM', tradingClass='NATIONALU'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=315530281, symbol='NBCC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NBCC', tradingClass='NBCC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984639, symbol='NCC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NCC', tradingClass='NCC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=64687316, symbol='NESTLEIND', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NESTLEIND', tradingClass='NESTLEIND'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=68324175, symbol='NHPC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NHPC', tradingClass='NHPC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984634, symbol='NIITTECH', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NIITTECH', tradingClass='NIITTECH'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984653, symbol='NMDC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NMDC', tradingClass='NMDC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=49982069, symbol='NTPC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='NTPC', tradingClass='NTPC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983625, symbol='OFSS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='OFSS', tradingClass='OFSS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=69422667, symbol='OIL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='OIL', tradingClass='OIL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=83845926, symbol='ONGC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ONGC', tradingClass='ONGC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983614, symbol='ORIENTBAN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ORIENTBANK', tradingClass='ORIENTBAN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986688, symbol='PAGEIND', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PAGEIND', tradingClass='PAGEIND'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=119653211, symbol='PCJEWELLE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PCJEWELLER', tradingClass='PCJEWELLE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986920, symbol='PEL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PEL', tradingClass='PEL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986960, symbol='PETRONET', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PETRONET', tradingClass='PETRONET'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986985, symbol='PFC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PFC', tradingClass='PFC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986764, symbol='PIDILITIN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PIDILITIND', tradingClass='PIDILITIN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=176235422, symbol='PNB', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PNB', tradingClass='PNB'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=50486118, symbol='POWERGRID', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='POWERGRID', tradingClass='POWERGRID'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987108, symbol='PVR', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='PVR', tradingClass='PVR'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56987148, symbol='RAMCOCEM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RAMCOCEM', tradingClass='RAMCOCEM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984932, symbol='RAYMOND', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RAYMOND', tradingClass='RAYMOND'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=246723708, symbol='RBLBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RBLBANK', tradingClass='RBLBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984788, symbol='RECLTD', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RECLTD', tradingClass='RECLTD'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56984773, symbol='RELCAPITA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RELCAPITAL', tradingClass='RELCAPITA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652000, symbol='RELIANCE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RELIANCE', tradingClass='RELIANCE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652170, symbol='RELINFRA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RELINFRA', tradingClass='RELINFRA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=125203631, symbol='REPCOHOME', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='REPCOHOME', tradingClass='REPCOHOME'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=53680378, symbol='RPOWER', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RPOWER', tradingClass='RPOWER'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652045, symbol='SAIL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SAIL', tradingClass='SAIL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=173418084, symbol='SBIN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SBIN', tradingClass='SBIN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56989171, symbol='SHREECEM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SHREECEM', tradingClass='SHREECEM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652105, symbol='SIEMENS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SIEMENS', tradingClass='SIEMENS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=79403920, symbol='SOUTHBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SOUTHBANK', tradingClass='SOUTHBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56989180, symbol='SRF', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SRF', tradingClass='SRF'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56988999, symbol='SRTRANSFI', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SRTRANSFIN', tradingClass='SRTRANSFI'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56989252, symbol='STAR', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='STAR', tradingClass='STAR'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=81351036, symbol='SUNPHARMA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SUNPHARMA', tradingClass='SUNPHARMA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56989289, symbol='SUNTV', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SUNTV', tradingClass='SUNTV'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=51687627, symbol='SUZLON', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SUZLON', tradingClass='SUZLON'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56989087, symbol='SYNDIBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='SYNDIBANK', tradingClass='SYNDIBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986895, symbol='TATACHEM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATACHEM', tradingClass='TATACHEM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652159, symbol='TATACOMM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATACOMM', tradingClass='TATACOMM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985222, symbol='TATAELXSI', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATAELXSI', tradingClass='TATAELXSI'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=76814483, symbol='TATAGLOBA', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATAGLOBAL', tradingClass='TATAGLOBA'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=94127580, symbol='TATAMOTOR', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATAMOTORS', tradingClass='TATAMOTOR'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=94127589, symbol='TATAMTRDV', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATAMTRDVR', tradingClass='TATAMTRDV'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=95168502, symbol='TATAPOWER', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATAPOWER', tradingClass='TATAPOWER'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652069, symbol='TATASTEEL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TATASTEEL', tradingClass='TATASTEEL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652015, symbol='TCS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TCS', tradingClass='TCS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=187395599, symbol='TECHM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TECHM', tradingClass='TECHM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=90181242, symbol='TITAN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TITAN', tradingClass='TITAN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986878, symbol='TORNTPHAR', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TORNTPHARM', tradingClass='TORNTPHAR'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986853, symbol='TORNTPOWE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TORNTPOWER', tradingClass='TORNTPOWE'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56985560, symbol='TV18BRDCS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TV18BRDCST', tradingClass='TV18BRDCS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56986838, symbol='TVSMOTOR', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='TVSMOTOR', tradingClass='TVSMOTOR'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983324, symbol='UBL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='UBL', tradingClass='UBL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=233076295, symbol='UJJIVAN', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='UJJIVAN', tradingClass='UJJIVAN'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983383, symbol='ULTRACEMC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ULTRACEMCO', tradingClass='ULTRACEMC'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983358, symbol='UNIONBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='UNIONBANK', tradingClass='UNIONBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983369, symbol='UPL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='UPL', tradingClass='UPL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56988951, symbol='VEDL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='VEDL', tradingClass='VEDL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=245502600, symbol='VGUARD', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='VGUARD', tradingClass='VGUARD'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983785, symbol='VOLTAS', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='VOLTAS', tradingClass='VOLTAS'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652030, symbol='WIPRO', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='WIPRO', tradingClass='WIPRO'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=56983303, symbol='WOCKPHARM', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='WOCKPHARMA', tradingClass='WOCKPHARM'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=289165584, symbol='YESBANK', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='YESBANK', tradingClass='YESBANK'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Stock(conId=44652165, symbol='ZEEL', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ZEEL', tradingClass='ZEEL'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Index(conId=51497778, symbol='NIFTY50', exchange='NSE', currency='INR', localSymbol='NIFTY50'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[]),
#  Ticker(contract=Index(conId=56994300, symbol='BANKNIFTY', exchange='NSE', currency='INR', localSymbol='BANKNIFTY'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[])]

# %%
[ib.reqTickers(q) for i in range(0, len(qcs), 50) for q in qcs[i: i+50]]

# %%
qs

# %%
    
    mdata = [ib.reqMktData(contract=q, genericTickList='456', snapshot=False, regulatorySnapshot=False) for i in range(0, len(qcs), 50) for q in qcs[i:i+50]]
    ib.sleep(10)
