# %%
from ib_insync import *
util.startLoop()
ib = IB().connect('127.0.0.1', 3000, clientId=5)

# %%
def myfunc(sender):
    print("event triggered by %s" % sender)

    
ib.updatePortfolioEvent += myfunc
# Out:
# Decode failed
# Traceback (most recent call last):
#   File "c:\users\kashir\appdata\local\programs\python\python37-32\lib\site-packages\ib_insync\client.py", line 279, in _onSocketHasData
#     self._decode(fields)
#   File "c:\users\kashir\appdata\local\programs\python\python37-32\lib\site-packages\ib_insync\client.py", line 380, in _decode
#     self.decoder.interpret(fields)
#   File "c:\users\kashir\appdata\local\programs\python\python37-32\lib\site-packages\ibapi-9.73.7-py3.7.egg\ibapi\decoder.py", line 1425, in interpret
#     handleInfo.processMeth(self, iter(fields))
#   File "c:\users\kashir\appdata\local\programs\python\python37-32\lib\site-packages\ibapi-9.73.7-py3.7.egg\ibapi\decoder.py", line 485, in processPortfolioValueMsg
#     unrealizedPNL, realizedPNL, accountName)
#   File "c:\users\kashir\appdata\local\programs\python\python37-32\lib\site-packages\ib_insync\wrapper.py", line 248, in updatePortfolio
#     self._ib.updatePortfolioEvent.emit(portfItem)
# ...
